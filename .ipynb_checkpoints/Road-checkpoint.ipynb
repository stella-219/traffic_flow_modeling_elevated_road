# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class Road:
    '''
    Road object in particle-based model with elevation profile
    '''
    def __init__(self, length, amplitude, frequency, phase_shift):
        """
        Create a non-linear road with multiple smooth slopes using sine functions.
        
        Args:
            length: Total length of the road (meters)
            amplitude: List of amplitudes for sine waves to control height variation.
            frequency: List of frequencies for sine waves to control wave tightness.
            phase_shift: List of phase shifts to offset the sine waves.
        """
        self.length = length
        self.amplitude = amplitude
        self.frequency = frequency
        self.phase_shift = phase_shift
    
    def generate_elevation(self):
        """
        Generate elevation points using a sine waves function.
        
        
        """
        x_values = np.linspace(0, self.length, 200)  # Higher resolution for smoothness
        y_values = np.zeros_like(x_values)
        
        for a, f, p in zip(self.amplitude, self.frequency, self.phase_shift):
            y_values += a * np.sin(2 * np.pi * f * x_values / self.length + p)
        
        return x_values, y_values
    
    def plot_road(self):
        """
        Plot the road's elevation profile with multiple smooth slopes.
        """
        x, y = self.generate_elevation()
        plt.figure(figsize=(10, 4))
        plt.plot(x, y, color='b', linestyle='-')
        plt.xlabel("Distance (m)")
        plt.ylabel("Elevation (m)")
        plt.title("Road Elevation Profile with Smooth Rolling Slopes")
        plt.grid(True)
        plt.show()
    
    def calculate_grade(self):
        """
        Calculate and return the grade of the road as a percentage.
        """
        x_values, y_values = self.generate_elevation()
        dy_dx = np.gradient(y_values, x_values)
        grades = (dy_dx * 100).tolist()  # Convert slope to percentage
        return grades

# %%
if __name__ == "__main__":
    # Define a road with smooth wavy slopes
    road = Road(
        length=1000, 
        amplitude=[3, 1.5, 2.5, 6, 10],  # Different hill heights
        frequency=[3, 2, 4, 5, 3],  # Different wave frequencies
        phase_shift=[0, np.pi / 1, np.pi /1, np.pi / 1, np.pi /1]  # Phase shift for wave mix
    )
    
    road.plot_road()
    print("Road Grades: ", road.calculate_grade())
# Out:
# Road Grades:  [-40.09652237791394, -39.750367610993834, -38.719048427762594, -37.02383831868437, -34.699657396454796, -31.794282170798873, -28.367265564814794, -24.488592737641035, -20.237104508053495, -15.698725634008825, -10.964539762462632, -6.1287564123803095, -1.2866178068313694, 3.4677053306796157, 8.043179784842547, 12.353889500273718, 16.320882940100056, 19.873845541298742, 22.952559000454322, 25.508114377309386, 27.503852037426192, 28.916008120862358, 29.734054357232903, 29.960725473971305, 29.611735982279264, 28.715195590070035, 27.310739701236415, 25.448398240531837, 23.187232228896782, 20.593772975803894, 17.740303322381802, 14.703023952737414, 11.560150306509415, 8.389987015217383, 5.269027018241457, 2.2701215896505977, -0.5392345484996897, -3.0984619826457394, -5.355262317217369, -7.2667589370977055, -8.800386702201536, -9.93451084943776, -10.658762229836405, -10.974083146195435, -10.8924853013248, -10.436528538764382, -9.63853597897624, -8.539567653420093, -7.188180656525832, -5.6390090261895125, -3.951200900321676, -2.1867538750423563, -0.4087918283553066, 1.320172283317464, 2.939943026939465, 4.394274864312566, 5.632388757532334, 6.610334602992015, 7
...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

class Road:
    """
    Road Object in a particle-based model with smooth elevation transitions using cubic splines.
    """
    
    def __init__(self, length, control_points):
        """
        Create a road using cubic splines for smooth elevation transitions.
        
        Args:
            length: Total length of the road (meters)
            control_points: List of (x, y) pairs representing elevation waypoints.
        """
        self.length = length
        self.control_points = control_points  # List of (x, y) control points
    
    def generate_elevation(self):
        """
        Generate elevation points using cubic splines.
        """
        # Extract x and y values from control points
        x_values, y_values = zip(*self.control_points)
        
        # Create cubic spline interpolation
        spline = CubicSpline(x_values, y_values, bc_type='natural')
        
        # Generate smooth elevation values
        x_smooth = np.linspace(0, self.length, 80)
        y_smooth = spline(x_smooth)
        
        return x_smooth, y_smooth
    
    def plot_road(self):
        """
        Plot the road's elevation profile with smooth slopes using cubic splines.
        """
        x, y = self.generate_elevation()
        plt.figure(figsize=(10, 4))
        plt.plot(x, y, color='b', linestyle='-')
        plt.scatter(*zip(*self.control_points), color='r', label='Control Points')
        plt.xlabel("Distance (m)")
        plt.ylabel("Elevation (m)")
        plt.title("Road Elevation Profile with Smooth Splines")
        plt.legend()
        plt.grid(True)
        plt.show()
    
    def calculate_grade(self):
        """
        Calculate and return the grade of the road as a percentage.
        """
        x_values, y_values = self.generate_elevation()
        dy_dx = np.gradient(y_values, x_values)
        grades = (dy_dx * 100).tolist()  # Convert slope to percentage
        return grades

# %%
# Example Usage
if __name__ == "__main__":
    # Define control points for a smooth road using splines
    control_points = [
        (0, 0), (100, 10), (200, 5), (300, 15), (400, 8), (500, 12),(600,20),(700,18),(800,12),(900,15),(1000,10)  # (distance, elevation)
    ]
    
    road = Road(1000, control_points)
    road.plot_road()
    print("Road Grades: ", road.calculate_grade())
# Out:
# Road Grades:  [15.383729000541397, 15.120723187129506, 14.33170574689383, 13.016676679834385, 11.17563598595115, 8.808583665244129, 5.915519717713346, 2.4965869761229778, -1.258532648641364, -4.597110489134748, -6.851831870916403, -7.918571708869165, -7.79733000299305, -6.4881067532880365, -3.9909019597541313, -0.30740211766583925, 4.20316927950967, 8.385562968744198, 11.334130987634591, 12.940937638613248, 13.205982921680187, 12.129266836835395, 9.710789384078867, 5.956050452692607, 1.2960784027029382, -3.122298000791557, -6.507909499595089, -8.79088712986596, -9.971230891604172, -10.048940784809702, -9.02401680948255, -6.9043498012114295, -4.004586829094814, -1.0299713238706654, 1.5943779471210118, 3.8418294137684494, 5.712383076071637, 7.206038934030579, 8.322796987645292, 9.063791466892003, 9.456243891200684, 9.552328839478774, 9.379267831156291, 8.938195096209345, 8.229110634638094, 7.252014446442468, 6.006906531622502, 4.500465219335581, 2.839296430577798, 1.200252215261155, -0.33776420434601384, -1.7727740640486878, -3.104777363847122, -4.333774103741073, -5.459764283730695, -6.4733208471339125, -7.267695431989118, -7.6881523848861155, -7.676535286177577, -7.232102064346102, -6.354852719391801, -5.0447872513145695, -3.3019056601145182, -1.169612210919424, 0.9879041841823033, 2.706082249994096, 3.840467166637329, 4.390380742469347, 4.355822977490254, 3.736793871699917, 2.5332934250984374, 0.7972742547359357, -1.1383107904730516, -2.8978920372026984, -4.3868287783984545, -5.605049748467749, -6.5525549474104885, -7.229344375226781, -7.635418031916519, -7.770775917479786]
